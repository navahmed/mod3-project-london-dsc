# %%
import pandas as pd

# %%
terry = pd.read_csv('Terry_cleaned.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np

# %%
import numpy as np
chosen_idx = np.random.choice(2000, replace=False, size=50)
df_trimmed = terry.iloc[chosen_idx]

# %%
df_trimmed
# Out:
#       Unnamed: 0  Unnamed: 0.1   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 1450        1450          1982           -1  20160000244252         172844
# 1615        1615          2210           -1  20170000091090         246858
# 510          510           819           -1  20180000062421         391525
# 1466        1466          1999           -1  20160000318471         189510
# 261          261           461           -1  20160000114005         142595
# 1916        1916          2555           -1  20180000020752         378633
# 1962        1962          2601           -1  20180000101193         401228
# 832          832          1194   8372748885  20190000230853     8372741288
# 148          148           249           -1  20150000406746         103896
# 1271        1271          1782           -1  20160000045846         126819
# 1313        1313          1824           -1  20160000135266         147667
# ...
